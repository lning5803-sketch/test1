# %% [markdown]
# # Exercise 12: Ultrasound (III)

# %% [markdown]
# > *Type name(s) of participant(s):*

# %% [markdown]
# ## Section 1: Doppler ultrasound
#
# Consider pulsed Doppler velocity measurement with the following specifications:
# * Ultrasound frequency: $\textrm{f} = 3.2 \,\textrm{MHz}$
# * Density of the medium: $\rho = 1.0 \,\frac{\textrm{g}}{\textrm{cm}^3}$
# * Impedance of the medium: $Z = 1.6 \cdot 10^6 \frac{\textrm{kg}}{\textrm{m}^2\textrm{s}}$

# %% [markdown]
# ### Task 1.1
# > What is the range of Doppler shifts that can be resolved unambiguously at a pulse repetition frequency of 1 kHz?

# %% [markdown]
# from nyquist sampling theorem ,$-\frac{1}{2} f_{prf}<f_i<\frac{1}{2} f_{prf}$ ,$-500Hz<f<500Hz$

# %% [markdown]
# ### Task 1.2
# > What is the corresponding range of velocities for motion along the direction of the ultrasound beam?

# %% [markdown]
# $c=\frac{c}{\rho}=1.6*10^3 m/s$,$v=\frac{f_DC}{2f_i cos\theta}$,$\theta=0$,$-0.125m/s<v<0.125m/s$

# %% [markdown]
# ### Task 1.3
# >How is spatial selectivity achieved in Doppler velocity measurements?

# %% [markdown]
# change the frequency of gating.

# %% [markdown]
# ## Section 2: Speckle noise

# %% [markdown]
# ### Task 2.1
# > What is the cause of speckle noise in ultrasound imaging?

# %% [markdown]
# interference of scattered waves

# %% [markdown]
# ### Task 2.2
# > What is the characteristic length of speckle noise?

# %% [markdown]
# $\lambda /2$

# %% [markdown]
# ### Task 2.3
# > How can speckle noise be mitigated?

# %% [markdown]
# multiple angles, images averaged
